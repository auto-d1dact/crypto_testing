# %% [markdown]
# # Filtering Microcap Alts

# %%
#%% Importing modules and data
import smtplib
import pandas as pd
import numpy as np
import datetime as dt
import pandas.stats.moments as st
from pandas import ExcelWriter
import matplotlib.pyplot as plt
import os
import quandl as qd
import seaborn as sns
import matplotlib.dates as dates
import matplotlib.ticker as ticker
from pandas_datareader import data
from lxml import html
import requests
import webbrowser
from bs4 import BeautifulSoup as bs
import json
import csv
import os
import glob
from time import sleep

# %% [markdown]
# # Functions for pulling from Coinmarketcap
# - coindfpull: pulls coin information from cmc including total coin supply
# - tokendfpull: pulls token information from cmc including total token supply
# - coincircdf: pulls coin circulating supply from cmc
# - tokencircdf: pulls token circulating supply from cmc

# %%
def coindfpull(pagenum):
    site = 'https://coinmarketcap.com/coins/views/market-cap-by-total-supply/' + str(pagenum)
    res = requests.get(site)
    if str(res) == "<Response [404]>":
        return "404 Response"
    
    soup = bs(res.text, 'lxml')

    table = soup.find_all('table')[0] 

    ranks = []
    currnames = []
    mcapsusd = []
    mcapsbtc = []
    pricesusd = []
    pricesbtc = []
    volumes24husd = []
    volumes24hbtc = []
    totalsupplies = []
    #changes24husd = []
    #changes24hbtc = []

    for row in table.find_all('tr'):
        columns = str(row).split('\n')
        if '#' in columns[1]:
            continue
        else:
            ranks = ranks + [columns[2].replace(' ','')]
            currnames = currnames + [columns[6].split('<span class="currency-symbol"><a href="/currencies/')[1].split('/')[0]]
            mcapsusd = mcapsusd + [columns[9].split('data-btc="')[1].split(' " data-usd="')[1].replace('">','')]
            mcapsbtc = mcapsbtc + [columns[9].split('data-btc="')[1].split(' " data-usd="')[0]]
            pricesusd = pricesusd + [columns[15].split('" data-btc="')[1].split('" data-usd="')[1].split('" ')[0]]
            pricesbtc = pricesbtc + [columns[15].split('" data-btc="')[1].split('" data-usd="')[0]]
            volumes24husd = volumes24husd + [columns[18].split('" data-btc="')[1].split('" data-usd="')[1].split('" ')[0]]
            volumes24hbtc = volumes24hbtc + [columns[18].split('" data-btc="')[1].split('" data-usd="')[0]]
            totalsupplies = totalsupplies + [columns[21].split('data-supply="')[1].split('" ')[0].replace('">','')]
            #changes24husd = changes24husd + [columns[-3].split('" data-btc="')[1].split('" data-usd="')[1].split('">')[0]]
            #changes24hbtc = changes24hbtc + [columns[-3].split('" data-btc="')[1].split('" data-usd="')[0]]
    
    crypto_dict = {"Rank": ranks,
                   "Names": currnames,
                   "MktCapUSD": mcapsusd,
                   "MktCapBTC": mcapsbtc,
                   "PricesUSD": pricesusd,
                   "PricesBTC": pricesbtc,
                   "Vol24USD": volumes24husd,
                   "Vol24BTC": volumes24hbtc,
                   "TotalSupply": totalsupplies}
                   #"Change24USD": changes24husd,
                   #"Change24BTC": changes24hbtc
                  #}
    
    outdf = pd.DataFrame(crypto_dict, index = currnames)
    
    return outdf

def tokendfpull(pagenum):
    site = 'https://coinmarketcap.com/tokens/views/market-cap-by-total-supply/' + str(pagenum)
    res = requests.get(site)
    if str(res) == "<Response [404]>":
        return "404 Response"
    
    soup = bs(res.text, 'lxml')

    table = soup.find_all('table')[0] 

    ranks = []
    currnames = []
    platforms = []
    mcapsusd = []
    mcapsbtc = []
    pricesusd = []
    pricesbtc = []
    volumes24husd = []
    volumes24hbtc = []
    totalsupplies = []
    #changes24husd = []
    #changes24hbtc = []

    for row in table.find_all('tr'):
        columns = str(row).split('\n')
        if '#' in columns[1]:
            continue
        else:
            ranks = ranks + [columns[2].replace(' ','')]
            platforms = platforms + [columns[0].split('data-platformsymbol="')[1].split('" ')[0]]
            currnames = currnames + [columns[6].split('<span class="currency-symbol"><a href="/currencies/')[1].split('/')[0]]
            mcapsusd = mcapsusd + [columns[10].split('data-btc="')[1].split(' " ')[1].split('data-usd="')[1].replace('">','')]
            mcapsbtc = mcapsbtc + [columns[10].split('data-btc="')[1].split(' " ')[0]]
            pricesusd = pricesusd + [columns[16].split('data-btc="')[1].split('" ')[2].replace('data-usd="','')]
            pricesbtc = pricesbtc + [columns[16].split('data-btc="')[1].split('" ')[0]]
            volumes24husd = volumes24husd + [columns[19].split('data-btc="')[1].split('" ')[2].replace('data-usd="','')]
            volumes24hbtc = volumes24hbtc + [columns[19].split('data-btc="')[1].split('" ')[0]]
            totalsupplies = totalsupplies + [columns[22].split('data-supply="')[1].split('" ')[0].replace('">','')]
            #changes24husd = changes24husd + [columns[-3].split('" data-btc="')[1].split('" data-usd="')[1].split('">')[0]]
            #changes24hbtc = changes24hbtc + [columns[-3].split('" data-btc="')[1].split('" data-usd="')[0].split('" ')[0]]
    
    crypto_dict = {"Rank": ranks,
                   "Names": currnames,
                   "Platform": platforms,
                   "MktCapUSD": mcapsusd,
                   "MktCapBTC": mcapsbtc,
                   "PricesUSD": pricesusd,
                   "PricesBTC": pricesbtc,
                   "Vol24USD": volumes24husd,
                   "Vol24BTC": volumes24hbtc,
                   "TotalSupply": totalsupplies}
                   #"Change24USD": changes24husd,
                   #"Change24BTC": changes24hbtc
                  #}
    
    outdf = pd.DataFrame(crypto_dict, index = currnames)
    
    return outdf

def coincircdf(pagenum):
    site = 'https://coinmarketcap.com/coins/' + str(pagenum)
    res = requests.get(site)
    if str(res) == "<Response [404]>":
        return "404 Response"
    
    soup = bs(res.text, 'lxml')

    table = soup.find_all('table')[0] 
    
    currnames = []
    circulatingsupplies = []

    for row in table.find_all('tr'):
        columns = str(row).split('\n')
        if '#' in columns[1]:
            continue
        else:
            currnames = currnames + [columns[6].split('<span class="currency-symbol"><a href="/currencies/')[1].split('/')[0]]
            circulatingsupplies = circulatingsupplies + [columns[21].split('data-supply="')[1].split('" ')[0].replace('">','')]
    
    crypto_dict = {"Names": currnames,
                   "CirculatingSupply": circulatingsupplies}
    
    outdf = pd.DataFrame(crypto_dict, index = currnames)
    del outdf['Names']
    
    return outdf

def tokencirdf(pagenum):
    site = 'https://coinmarketcap.com/tokens/' + str(pagenum)
    res = requests.get(site)
    if str(res) == "<Response [404]>":
        return "404 Response"
    
    soup = bs(res.text, 'lxml')

    table = soup.find_all('table')[0] 
    
    currnames = []
    circulatingsupplies = []

    for row in table.find_all('tr'):
        columns = str(row).split('\n')
        if '#' in columns[1]:
            continue
        else:
            currnames = currnames + [columns[6].split('<span class="currency-symbol"><a href="/currencies/')[1].split('/')[0]]
            circulatingsupplies = circulatingsupplies + [columns[22].split('data-supply="')[1].split('" ')[0].replace('">','')]
    
    crypto_dict = {"Names": currnames,
                   "CirculatingSupply": circulatingsupplies}
    
    outdf = pd.DataFrame(crypto_dict, index = currnames)
    del outdf['Names']
    
    return outdf

# %% [markdown]
# # Alternative Function for Pulling all Coin/Token Caps

# %%
def pullfulldf():
    site = 'https://coinmarketcap.com/all/views/all/'
    res = requests.get(site)
    soup = bs(requests.get(site).text, "lxml")

    table_start = '<table class="table js-summary-table dataTable no-footer" id="currencies-all" style="font-size: 14px; width: 100%;" role="grid">'
    table_end = '</table>'

    table = soup.find_all('table')[0]

    symbol = []
    cname = []
    mcapsusd = []
    pricesusd = []
    pricesbtc = []
    volumes24husd = []
    totalsupplies = []
    availablesupplies = []
    maxsupplies = []
    change1h = []
    change24h = []
    change7d = []
    i = 1
    for row in table.find_all('tr'):
        columns = str(row).split('\n')
        if not('class' in columns[0]):
            continue

        cmcname = columns[0].split('"id-')[1].replace('">','')

        apisite = 'https://api.coinmarketcap.com/v1/ticker/' + cmcname + '/'
        response = requests.get(apisite)
        json_data = json.loads(response.text)

        cname = cname + [cmcname]
        symbol = symbol + [json_data[0]['symbol']]
        mcapsusd = mcapsusd + [json_data[0]['market_cap_usd']]
        pricesusd = pricesusd + [json_data[0]['price_usd']]
        pricesbtc = pricesbtc + [json_data[0]['price_btc']]
        volumes24husd = volumes24husd + [json_data[0]['24h_volume_usd']]
        totalsupplies = totalsupplies + [json_data[0]['total_supply']]
        availablesupplies = availablesupplies + [json_data[0]['available_supply']]
        maxsupplies = maxsupplies + [json_data[0]['max_supply']]
        change1h = change1h + [json_data[0]['percent_change_1h']]
        change24h = change24h + [json_data[0]['percent_change_24h']]
        change7d = change7d + [json_data[0]['percent_change_7d']]
        
        print('Number: ' + str(i) + ' Coin: ' + json_data[0]['symbol'])
        sleep(1)
        i += 1

    fulldict = {'CMCname': cname,
                'Symbol': symbol,
                'Mcap': mcapsusd,
                'USDPrice': pricesusd,
                'BTCPrice': pricesbtc,           
                'Vol24h': volumes24husd,           
                'TotalSupply': totalsupplies,           
                'AvailableSupply': availablesupplies,    
                'MaxSupply': maxsupplies,
                'Change1h': change1h,
                'Change24h': change24h,
                'Change7d': change7d}
    fulldf = pd.DataFrame(fulldict,index = cname)
    
    return fulldf

# %% [markdown]
# # Creating dataframe for initial filtering
# - Keep only marketcaps with less than 100M
# - Remove tokens with 24 hour volumes less than 2% of marketcaps
# - Remove tokens with circulating supply/total supply with less than 20%

# %%
# Creating DF for Coins

def microfilter1(mcapthreshold, volthreshold, supplythreshold):
    pagenmbr = 1
    coinlist = []
    while type(coindfpull(pagenmbr)) != str:
        coinlist = coinlist + [coindfpull(pagenmbr)]
        pagenmbr += 1

    pagenmbr = 1
    coincirclist = []
    while type(coincircdf(pagenmbr)) != str:
        coincirclist = coincirclist + [coincircdf(pagenmbr)]
        pagenmbr += 1

    coinscirc = pd.concat(coincirclist, axis = 0)
    coins = pd.concat(coinlist, axis = 0)
    coins = coins[coins['MktCapUSD'] != '?']
    coins = pd.concat([coins.drop_duplicates(),coinscirc.drop_duplicates()], axis = 1, join = 'inner')

    # Creating DF for Tokens

    pagenmbr = 1
    tokenlist = []
    while type(tokendfpull(pagenmbr)) != str:
        tokenlist = tokenlist + [tokendfpull(pagenmbr)]
        pagenmbr += 1

    pagenmbr = 1
    tokencirclist = []
    while type(tokencirdf(pagenmbr)) != str:
        tokencirclist = tokencirclist + [tokencirdf(pagenmbr)]
        pagenmbr += 1

    tokenscirc = pd.concat(tokencirclist, axis = 0)
    tokens = pd.concat(tokenlist, axis = 0)
    tokens = tokens[tokens['MktCapUSD'] != '?']
    tokens = pd.concat([tokens.drop_duplicates(),tokenscirc.drop_duplicates()], axis = 1, join = 'inner')

    totaldf = pd.concat([coins,tokens], axis = 0)
    totaldf = totaldf[totaldf['CirculatingSupply'] != 'None']
    totaldf = totaldf[totaldf['Vol24USD'] != 'None']

    totaldf['MktCapUSD'] = pd.to_numeric(totaldf['MktCapUSD'])
    totaldf['CirculatingSupply'] = pd.to_numeric(totaldf['CirculatingSupply'])
    totaldf['TotalSupply'] = pd.to_numeric(totaldf['TotalSupply'])
    totaldf['Vol24USD'] = pd.to_numeric(totaldf['Vol24USD'])
    totaldf['VolRatio'] = totaldf['Vol24USD']/totaldf['MktCapUSD']
    totaldf['SupplyRatio'] = totaldf['CirculatingSupply']/totaldf['TotalSupply']
    
    totaldf = totaldf[totaldf['MktCapUSD'] <= mcapthreshold]
    totaldf = totaldf[totaldf['VolRatio'] >= volthreshold]
    totaldf = totaldf[totaldf['SupplyRatio'] >= supplythreshold]
    
    
    return totaldf

# %%
def checkannouncement(cmcname):

    site = 'https://coinmarketcap.com/currencies/' + cmcname + '/'

    res = requests.get(site)
    soup = str(bs(res.text, 'lxml'))

    if "Announcement" in soup:
        announcementsite = soup.split('<li><span class="glyphicon glyphicon-bullhorn text-gray" title="Announcement">')[1].split('<a href="')[1].split('" target')[0]
    else:
        announcementsite = "NA"

    if 'bitcointalk.org' in announcementsite:
        return 1, announcementsite
    else:
        return 0, 'NA'
    
def bctcheck(cmcname):

    annsite = checkannouncement(cmcname)[1]
    parsesoup = annsite.split('=')[0] + '=' + annsite.split('=')[1].split('.')[0]
    res = requests.get(parsesoup)
    soup = str(bs(res.text, 'lxml'))
    discussion = soup.split('<td class="middletext"')[1].split('<span class="prevnext">')[0]
    discussion = discussion.split('<div class="nav"')[0]
    if 'All' in discussion.split(parsesoup)[-1]:
        lastdiscuss = discussion.split(parsesoup)[-2]
    else:
        lastdiscuss = discussion.split(parsesoup)[-1]
        
    if '<td align="right" style="padding-right:' in discussion:
        lastpgIndex = lastdiscuss.split('">')[0]
    else:
        lastpgIndex = lastdiscuss.split('">')[0]

    lastpg = parsesoup + lastpgIndex
    res = requests.get(lastpg)
    soup = str(bs(res.text, 'lxml'))
    totpages = soup.split('<td class="middletext"')[1].split('[<b>')[1].split('</b>]')[0]

    forumparse = lastpg.split('=')[1]
    res = requests.get(lastpg)
    soup = str(bs(res.text, 'lxml'))
    lastmsg = soup.split(forumparse)[1].split('<tbody>')[-1].split('<div class="smalltext">')[-1].split('</div>')[0]
    
    return totpages, lastmsg

# %%
'''
# Using old method to build dataframe, no change fields available

cmcdf = microfilter1(100000000, 0.02, 0.1)

names = list(cmcdf.index)
announcements = []
bctpages = []
lastentries = []

for cmcname in names:
    bctentry, annsite = checkannouncement(cmcname)
    announcements = announcements + [bctentry]
    if bctentry == 1:
        totpgs, last = bctcheck(cmcname)
    else:
        totpgs, last = (0,0)
        
    bctpages = bctpages + [totpgs]
    lastentries = lastentries + [last]
    print('Name: ' + str(len(bctpages)) + ' Alt: ' + cmcname)
    sleep(1)
    
bctdf = pd.DataFrame({'bctpages': bctpages,
                     'lastentry': lastentries},
                    index = names)
filterdf = pd.concat([cmcdf,bctdf],axis = 1)
filterdf.to_csv('cmc2.csv')

'''

# %%
cmcfull = pullfulldf()

names = list(cmcfull.index)
announcements = []
bctpages = []
lastentries = []

for cmcname in names:
    bctentry, annsite = checkannouncement(cmcname)
    announcements = announcements + [bctentry]
    if bctentry == 1:
        try:
            totpgs, last = bctcheck(cmcname)
        except:
            totpgs, last = (0,0)
        
    else:
        totpgs, last = (0,0)
        
    bctpages = bctpages + [totpgs]
    lastentries = lastentries + [last]
    print('Name: ' + str(len(bctpages)) + ' Alt: ' + cmcname)
    sleep(1)
    
bctdf = pd.DataFrame({'bctpages': bctpages,
                     'lastentry': lastentries},
                    index = names)
filterdf = pd.concat([cmcfull,bctdf],axis = 1)

binance = pd.read_csv('binancelist.csv')
binance.index = binance['Name']
del binance['Ticker'], binance['Name']

bittrex = pd.read_excel('bittrexlist.xlsx')
bittrex.index = bittrex['Name']
del bittrex['Ticker'], bittrex['Name']

kucoin = pd.read_csv('kucoinlist.csv')
kucoin.index = kucoin['Name']
del kucoin['Ticker'], kucoin['Name']

cryptopia = pd.read_csv('cryptopialist.csv')
cryptopia.index = cryptopia['Name']
del cryptopia['Ticker'], cryptopia['Name']

fulldf = pd.concat([filterdf,cryptopia,kucoin,binance,bittrex],axis = 1)
fulldf.head()

fulldf.to_csv('cmc.csv')
# Out:
# Number: 1 Coin: BTC
# Number: 2 Coin: ETH
# Number: 3 Coin: XRP
# Number: 4 Coin: BCH
# Number: 5 Coin: ADA
# Number: 6 Coin: XEM
# Number: 7 Coin: LTC
# Number: 8 Coin: XLM
# Number: 9 Coin: MIOTA
# Number: 10 Coin: TRX
# Number: 11 Coin: DASH
# Number: 12 Coin: NEO
# Number: 13 Coin: XMR
# Number: 14 Coin: EOS
# Number: 15 Coin: ICX
# Number: 16 Coin: QTUM
# Number: 17 Coin: BTG
# Number: 18 Coin: LSK
# Number: 19 Coin: XRB
# Number: 20 Coin: ETC
# Number: 21 Coin: XVG
# Number: 22 Coin: SC
# Number: 23 Coin: OMG
# Number: 24 Coin: BCN
# Number: 25 Coin: BCC
# Number: 26 Coin: ZEC
# Name: 22 Alt: siacoin
# Name: 23 Alt: omisego
# Name: 24 Alt: bytecoin-bcn
# Name: 25 Alt: bitconnect
# Name: 26 Alt: zcash
# Name: 27 Alt: populous
# Name: 28 Alt: stratis
# Name: 29 Alt: bitshares
# Name: 30 Alt: binance-coin
# Name: 31 Alt: dogecoin
# Name: 32 Alt: ardor
# Name: 33 Alt: status
# Name: 34 Alt: dentacoin
# Name: 35 Alt: kucoin-shares
# Name: 36 Alt: steem
# Name: 37 Alt: tether
# Name: 38 Alt: waves
# Name: 39 Alt: vechain
# Name: 40 Alt: dragonchain
# Name: 41 Alt: augur
# Name: 42 Alt: digibyte
# Name: 43 Alt: komodo
# Name: 44 Alt: dent
# Name: 45 Alt: golem-network-tokens
# Name: 46 Alt: 0x
# Name: 47 Alt: veritaseum
# Name: 48 Alt: hshare
# Name: 49 Alt: ark
# Name: 50 Alt: basic-attention-token
# Name: 51 Alt: electroneum
# Name: 52 Alt: salt
# Name: 53 Alt: funfair
# Name: 54 Alt: kin
# Name: 55 Alt: decred
# Name: 56 Alt: ethos
# Name: 57 Alt: reddcoin
# Name: 58 Alt: nexus
# Name: 59 Alt: experience-points
# Name: 60 Alt: factom
# Name: 61 Alt: kyber-network
# Name: 62 Alt: pivx
# Name: 63 Alt: qash
# Name: 64 Alt: request-network
# Name: 65 Alt: wax
# Name: 66 Alt: power-ledger
# Name: 67 Alt: aeternity
# Name: 68 Alt: neblio
# Name: 69 Alt: aion
# Name: 70 Alt: aelf
# Name: 71 Alt: bytom
# Name: 72 Alt: substratum
# Name: 73 Alt: digitalnote
# Name: 74 Alt: rchain
# Name: 75 Alt: monacoin
# Name: 76 Alt: bitcoindark
# Name: 77 Alt: nxt
# Name: 78 Alt: enigma-project
# Name: 79 Alt: maidsafecoin
# Name: 80 Alt: time-new-bank
# Name: 81 Alt: syscoin
# Name: 82 Alt: byteball
# Name: 83 Alt: gas
# Name: 84 Alt: chainlink
# Name: 85 Alt: medibloc
# Name: 86 Alt: santiment
# Name: 87 Alt: quantstamp
# Name: 88 Alt: tenx
# Name: 89 Alt: iconomi
# Name: 90 Alt: deepbrain-chain
# Name: 91 Alt: digixdao
# Name: 92 Alt: gnosis-gno
# Name: 93 Alt: zcoin
# Name: 94 Alt: red-pulse
# Name: 95 Alt: poet
# Name: 96 Alt: paccoin
# Name: 97 Alt: walton
# Name: 98 Alt: civic
# Name: 99 Alt: raiden-network-token
# Name: 100 Alt: storm
# Name: 101 Alt: blockv
# Name: 102 Alt: cobinhood
# Name: 103 Alt: bancor
# Name: 104 Alt: ethlend
# Name: 105 Alt: zclassic
# Name: 106 Alt: gamecredits
# Name: 107 Alt: achain
# Name: 108 Alt: gxshares
# Name: 109 Alt: vertcoin
# Name: 110 Alt: pillar
# Name: 111 Alt: enjin-coin
# Name: 112 Alt: storj
# Name: 113 Alt: skycoin
# Name: 114 Alt: xtrabytes
# Name: 115 Alt: blocknet
# Name: 116 Alt: unikoin-gold
# Name: 117 Alt: decentraland
# Name: 118 Alt: ubiq
# Name: 119 Alt: bitbay
# Name: 120 Alt: singulardtv
# Name: 121 Alt: monaco
# Name: 122 Alt: nav-coin
# Name: 123 Alt: cindicator
# Name: 124 Alt: xplay
# Name: 125 Alt: sirin-labs-token
# Name: 126 Alt: cryptonex
# Name: 127 Alt: attention-token-of-media
# Name: 128 Alt: revain
# Name: 129 Alt: aragon
# Name: 130 Alt: dynamic-trading-rights
# Name: 131 Alt: modum
# Name: 132 Alt: centra
# Name: 133 Alt: cybermiles
# Name: 134 Alt: edgeless
# Name: 135 Alt: smartcash
# Name: 136 Alt: sonm
# Name: 137 Alt: airswap
# Name: 138 Alt: streamr-datacoin
# Name: 139 Alt: ripio-credit-network
# Name: 140 Alt: paypie
# Name: 141 Alt: emercoin
# Name: 142 Alt: flash
# Name: 143 Alt: bridgecoin
# Name: 144 Alt: rlc
# Name: 145 Alt: district0x
# Name: 146 Alt: amber
# Name: 147 Alt: firstblood
# Name: 148 Alt: adx-net
# Name: 149 Alt: iot-chain
# Name: 150 Alt: particl
# Name: 151 Alt: triggers
# Name: 152 Alt: einsteinium
# Name: 153 Alt: wabi
# Name: 154 Alt: shield-xsh
# Name: 155 Alt: burst
# Name: 156 Alt: viacoin
# Name: 157 Alt: mobilego
# Name: 158 Alt: wings
# Name: 159 Alt: bread
# Name: 160 Alt: simple-token
# Name: 161 Alt: decision-token
# Name: 162 Alt: nuls
# Name: 163 Alt: peercoin
# Name: 164 Alt: metaverse
# Name: 165 Alt: counterparty
# Name: 166 Alt: utrust
# Name: 167 Alt: tierion
# Name: 168 Alt: melon
# Name: 169 Alt: zencash
# Name: 170 Alt: etherparty
# Name: 171 Alt: decent
# Name: 172 Alt: quantum-resistant-ledger
# Name: 173 Alt: eidoo
# Name: 174 Alt: library-credit
# Name: 175 Alt: spankchain
# Name: 176 Alt: hempcoin
# Name: 177 Alt: mooncoin
# Name: 178 Alt: agoras-tokens
# Name: 179 Alt: rise
# Name: 180 Alt: aeon
# Name: 181 Alt: cloakcoin
# Name: 182 Alt: metal
# Name: 183 Alt: coindash
# Name: 184 Alt: asch
# Name: 185 Alt: shift
# Name: 186 Alt: wagerr
# Name: 187 Alt: genesis-vision
# Name: 188 Alt: voxels
# Name: 189 Alt: oyster-pearl
# Name: 190 Alt: latoken
# Name: 191 Alt: coss
# Name: 192 Alt: groestlcoin
# Name: 193 Alt: presearch
# Name: 194 Alt: pura
# Name: 195 Alt: snovio
# Name: 196 Alt: adtoken
# Name: 197 Alt: gifto
# Name: 198 Alt: gulden
# Name: 199 Alt: jinn
# Name: 200 Alt: delphy
# Name: 201 Alt: lunyr
# Name: 202 Alt: grid
# Name: 203 Alt: trust
# Name: 204 Alt: feathercoin
# Name: 205 Alt: yoyow
# Name: 206 Alt: ink
# Name: 207 Alt: cofound-it
# Name: 208 Alt: bounty0x
# Name: 209 Alt: guppy
# Name: 210 Alt: monetha
# Name: 211 Alt: ixledger
# Name: 212 Alt: spectrecoin
# Name: 213 Alt: viberate
# Name: 214 Alt: salus
# Name: 215 Alt: loopring
# Name: 216 Alt: iocoin
# Name: 217 Alt: everex
# Name: 218 Alt: mysterium
# Name: 219 Alt: airtoken
# Name: 220 Alt: supernet-unity
# Name: 221 Alt: humaniq
# Name: 222 Alt: encrypgen
# Name: 223 Alt: datum
# Name: 224 Alt: mercury
# Name: 225 Alt: synereo
# Name: 226 Alt: agrello-delta
# Name: 227 Alt: taas
# Name: 228 Alt: eccoin
# Name: 229 Alt: namecoin
# Name: 230 Alt: worldcore
# Name: 231 Alt: crown
# Name: 232 Alt: vibe
# Name: 233 Alt: zeusshield
# Name: 234 Alt: potcoin
# Name: 235 Alt: pepe-cash
# Name: 236 Alt: solarcoin
# Name: 237 Alt: bitcny
# Name: 238 Alt: pascal-coin
# Name: 239 Alt: propy
# Name: 240 Alt: nolimitcoin
# Name: 241 Alt: tokencard
# Name: 242 Alt: minexcoin
# Name: 243 Alt: colossuscoinxt
# Name: 244 Alt: nimiq
# Name: 245 Alt: elixir
# Name: 246 Alt: dimecoin
# Name: 247 Alt: publica
# Name: 248 Alt: blackcoin
# Name: 249 Alt: blocktix
# Name: 250 Alt: neumark
# Name: 251 Alt: elastic
# Name: 252 Alt: sibcoin
# Name: 253 Alt: rivetz
# Name: 254 Alt: diamond
# Name: 255 Alt: paypex
# Name: 256 Alt: domraider
# Name: 257 Alt: mintcoin
# Name: 258 Alt: gridcoin
# Name: 259 Alt: suncontract
# Name: 260 Alt: ion
# Name: 261 Alt: blockmason
# Name: 262 Alt: e-coin
# Name: 263 Alt: moeda-loyalty-points
# Name: 264 Alt: peerplays-ppy
# Name: 265 Alt: stox
# Name: 266 Alt: newyorkcoin
# Name: 267 Alt: faircoin
# Name: 268 Alt: life
# Name: 269 Alt: change
# Name: 270 Alt: neoscoin
# Name: 271 Alt: aeron
# Name: 272 Alt: bitbean
# Name: 273 Alt: expanse
# Name: 274 Alt: lomocoin
# Name: 275 Alt: nushares
# Name: 276 Alt: monetaryunit
# Name: 277 Alt: myriad
# Name: 278 Alt: musicoin
# Name: 279 Alt: lockchain
# Name: 280 Alt: omni
# Name: 281 Alt: mothership
# Name: 282 Alt: sprouts
# Name: 283 Alt: numeraire
# Name: 284 Alt: heat-ledger
# Name: 285 Alt: playkey
# Name: 286 Alt: whitecoin
# Name: 287 Alt: hive
# Name: 288 Alt: deeponion
# Name: 289 Alt: divi
# Name: 290 Alt: target-coin
# Name: 291 Alt: golos
# Name: 292 Alt: phore
# Name: 293 Alt: bitcore
# Name: 294 Alt: flixxo
# Name: 295 Alt: nexium
# Name: 296 Alt: fedoracoin
# Name: 297 Alt: lykke
# Name: 298 Alt: rialto
# Name: 299 Alt: oax
# Name: 300 Alt: autonio
# Name: 301 Alt: espers
# Name: 302 Alt: atbcoin
# Name: 303 Alt: radium
# Name: 304 Alt: maecenas
# Name: 305 Alt: ethereum-blue
# Name: 306 Alt: credo
# Name: 307 Alt: foldingcoin
# Name: 308 Alt: rubycoin
# Name: 309 Alt: dovu
# Name: 310 Alt: okcash
# Name: 311 Alt: kickico
# Name: 312 Alt: clearpoll
# Name: 313 Alt: earthcoin
# Name: 314 Alt: bodhi
# Name: 315 Alt: voisecom
# Name: 316 Alt: steem-dollars
# Name: 317 Alt: vericoin
# Name: 318 Alt: alis
# Name: 319 Alt: patientory
# Name: 320 Alt: decent-bet
# Name: 321 Alt: ecobit
# Name: 322 Alt: global-currency-reserve
# Name: 323 Alt: linda
# Name: 324 Alt: bismuth
# Name: 325 Alt: xenon
# Name: 326 Alt: geocoin
# Name: 327 Alt: polybius
# Name: 328 Alt: zoin
# Name: 329 Alt: primas
# Name: 330 Alt: verify
# Name: 331 Alt: hedge
# Name: 332 Alt: aventus
# Name: 333 Alt: pinkcoin
# Name: 334 Alt: databits
# Name: 335 Alt: circuits-of-value
# Name: 336 Alt: stealthcoin
# Name: 337 Alt: incent
# Name: 338 Alt: open-trading-network
# Name: 339 Alt: paragon
# Name: 340 Alt: swarm-city
# Name: 341 Alt: clams
# Name: 342 Alt: mercury-protocol
# Name: 343 Alt: blackmoon-crypto
# Name: 344 Alt: cvcoin
# Name: 345 Alt: florincoin
# Name: 346 Alt: posw-coin
# Name: 347 Alt: gambit
# Name: 348 Alt: dubaicoin-dbix
# Name: 349 Alt: quantum
# Name: 350 Alt: investfeed
# Name: 351 Alt: obsidian
# Name: 352 Alt: sportyfi
# Name: 353 Alt: waves-community-token
# Name: 354 Alt: ormeus-coin
# Name: 355 Alt: bitqy
# Name: 356 Alt: noblecoin
# Name: 357 Alt: carboncoin
# Name: 358 Alt: opus
# Name: 359 Alt: icos
# Name: 360 Alt: chronobank
# Name: 361 Alt: hush
# Name: 362 Alt: soarcoin
# Name: 363 Alt: internet-of-people
# Name: 364 Alt: boolberry
# Name: 365 Alt: bcap
# Name: 366 Alt: 1337coin
# Name: 367 Alt: dao-casino
# Name: 368 Alt: pandacoin-pnd
# Name: 369 Alt: energycoin
# Name: 370 Alt: oraclechain
# Name: 371 Alt: vsync-vsx
# Name: 372 Alt: bitsend
# Name: 373 Alt: mybit-token
# Name: 374 Alt: mywish
# Name: 375 Alt: artbyte
# Name: 376 Alt: trueflip
# Name: 377 Alt: solaris
# Name: 378 Alt: sequence
# Name: 379 Alt: spreadcoin
# Name: 380 Alt: blockcat
# Name: 381 Alt: wild-crypto
# Name: 382 Alt: bitusd
# Name: 383 Alt: alqo
# Name: 384 Alt: lampix
# Name: 385 Alt: russian-mining-coin
# Name: 386 Alt: curecoin
# Name: 387 Alt: vcash
# Name: 388 Alt: upfiring
# Name: 389 Alt: bitmark
# Name: 390 Alt: primecoin
# Name: 391 Alt: zeitcoin
# Name: 392 Alt: bitdice
# Name: 393 Alt: qwark
# Name: 394 Alt: firstcoin
# Name: 395 Alt: bitcrystals
# Name: 396 Alt: etheroll
# Name: 397 Alt: obits
# Name: 398 Alt: flypme
# Name: 399 Alt: bulwark
# Name: 400 Alt: sharechain
# Name: 401 Alt: sphere
# Name: 402 Alt: cannabiscoin
# Name: 403 Alt: oxycoin
# Name: 404 Alt: neutron
# Name: 405 Alt: transfercoin
# Name: 406 Alt: dopecoin
# Name: 407 Alt: breakout
# Name: 408 Alt: intensecoin
# Name: 409 Alt: sumokoin
# Name: 410 Alt: dcorp
# Name: 411 Alt: unobtanium
# Name: 412 Alt: dotcoin
# Name: 413 Alt: payfair
# Name: 414 Alt: crowdcoin
# Name: 415 Alt: pesetacoin
# Name: 416 Alt: leocoin
# Name: 417 Alt: buzzcoin
# Name: 418 Alt: pluton
# Name: 419 Alt: nvo
# Name: 420 Alt: monacocoin
# Name: 421 Alt: exchange-union
# Name: 422 Alt: hyperstake
# Name: 423 Alt: privatix
# Name: 424 Alt: goldcoin
# Name: 425 Alt: synergy
# Name: 426 Alt: atmos
# Name: 427 Alt: encryptotel
# Name: 428 Alt: luxcoin
# Name: 429 Alt: 2give
# Name: 430 Alt: bitzeny
# Name: 431 Alt: gobyte
# Name: 432 Alt: memetic
# Name: 433 Alt: creditbit
# Name: 434 Alt: royal-kingdom-coin
# Name: 435 Alt: belacoin
# Name: 436 Alt: straks
# Name: 437 Alt: bitcoin-plus
# Name: 438 Alt: b2bx
# Name: 439 Alt: xaurum
# Name: 440 Alt: startcoin
# Name: 441 Alt: syndicate
# Name: 442 Alt: dnotes
# Name: 443 Alt: breakout-stake
# Name: 444 Alt: eboostcoin
# Name: 445 Alt: internxt
# Name: 446 Alt: universal-currency
# Name: 447 Alt: bitdeal
# Name: 448 Alt: the-champcoin
# Name: 449 Alt: blitzcash
# Name: 450 Alt: rupee
# Name: 451 Alt: social-send
# Name: 452 Alt: pirl
# Name: 453 Alt: social
# Name: 454 Alt: auroracoin
# Name: 455 Alt: sexcoin
# Name: 456 Alt: trezarcoin
# Name: 457 Alt: veriumreserve
# Name: 458 Alt: arcade-token
# Name: 459 Alt: hubii-network
# Name: 460 Alt: asiacoin
# Name: 461 Alt: novacoin
# Name: 462 Alt: korecoin
# Name: 463 Alt: riecoin
# Name: 464 Alt: innova
# Name: 465 Alt: indorse-token
# Name: 466 Alt: hellogold
# Name: 467 Alt: apx
# Name: 468 Alt: qvolta
# Name: 469 Alt: hollywoodcoin
# Name: 470 Alt: exclusivecoin
# Name: 471 Alt: quark
# Name: 472 Alt: blockpool
# Name: 473 Alt: ufo-coin
# Name: 474 Alt: bitcloud
# Name: 475 Alt: nubits
# Name: 476 Alt: chaincoin
# Name: 477 Alt: toacoin
# Name: 478 Alt: masternodecoin
# Name: 479 Alt: bitboost
# Name: 480 Alt: adshares
# Name: 481 Alt: parkbyte
# Name: 482 Alt: vtorrent
# Name: 483 Alt: real-estate-tokens
# Name: 484 Alt: real
# Name: 485 Alt: eroscoin
# Name: 486 Alt: bitcoinz
# Name: 487 Alt: putincoin
# Name: 488 Alt: bunnycoin
# Name: 489 Alt: pure
# Name: 490 Alt: ixcoin
# Name: 491 Alt: prospectors-gold
# Name: 492 Alt: project-decorum
# Name: 493 Alt: trustplus
# Name: 494 Alt: vivo
# Name: 495 Alt: e-dinar-coin
# Name: 496 Alt: unify
# Name: 497 Alt: zephyr
# Name: 498 Alt: magi
# Name: 499 Alt: greencoin
# Name: 500 Alt: europecoin
# Name: 501 Alt: ellaism
# Name: 502 Alt: campuscoin
# Name: 503 Alt: crave
# Name: 504 Alt: anoncoin
# Name: 505 Alt: astro
# Name: 506 Alt: farad
# Name: 507 Alt: xgox
# Name: 508 Alt: prizm
# Name: 509 Alt: dynamic
# Name: 510 Alt: evergreencoin
# Name: 511 Alt: bonpay
# Name: 512 Alt: force
# Name: 513 Alt: zrcoin
# Name: 514 Alt: vslice
# Name: 515 Alt: dinastycoin
# Name: 516 Alt: magnet
# Name: 517 Alt: creativecoin
# Name: 518 Alt: terracoin
# Name: 519 Alt: linx
# Name: 520 Alt: digipulse
# Name: 521 Alt: footy-cash
# Name: 522 Alt: altcoin-alt
# Name: 523 Alt: cryptoping
# Name: 524 Alt: eltcoin
# Name: 525 Alt: worldcoin
# Name: 526 Alt: embers
# Name: 527 Alt: atlant
# Name: 528 Alt: litedoge
# Name: 529 Alt: audiocoin
# Name: 530 Alt: student-coin
# Name: 531 Alt: karbowanec
# Name: 532 Alt: equitrader
# Name: 533 Alt: tokes
# Name: 534 Alt: bitswift
# Name: 535 Alt: huntercoin
# Name: 536 Alt: interstellar-holdings
# Name: 537 Alt: bowhead
# Name: 538 Alt: netcoin
# Name: 539 Alt: dfscoin
# Name: 540 Alt: procurrency
# Name: 541 Alt: smartbillions
# Name: 542 Alt: martexcoin
# Name: 543 Alt: goodomy
# Name: 544 Alt: cryptonite
# Name: 545 Alt: denarius-dnr
# Name: 546 Alt: bluecoin
# Name: 547 Alt: mazacoin
# Name: 548 Alt: fluttercoin
# Name: 549 Alt: ebtcnew
# Name: 550 Alt: fujicoin
# Name: 551 Alt: neverdie
# Name: 552 Alt: cryptoforecast
# Name: 553 Alt: miners-reward-token
# Name: 554 Alt: arcticcoin
# Name: 555 Alt: yocoin
# Name: 556 Alt: erc20
# Name: 557 Alt: gimli
# Name: 558 Alt: regalcoin
# Name: 559 Alt: the-cypherfunks
# Name: 560 Alt: cartaxi-token
# Name: 561 Alt: emphy
# Name: 562 Alt: flik
# Name: 563 Alt: mcap
# Name: 564 Alt: ergo
# Name: 565 Alt: e-gulden
# Name: 566 Alt: digitalprice
# Name: 567 Alt: renos
# Name: 568 Alt: thegcccoin
# Name: 569 Alt: hawala-today
# Name: 570 Alt: b3coin
# Name: 571 Alt: ethbits
# Name: 572 Alt: luckchain
# Name: 573 Alt: fastcoin
# Name: 574 Alt: primalbase
# Name: 575 Alt: draftcoin
# Name: 576 Alt: bytecent
# Name: 577 Alt: octanox
# Name: 578 Alt: ethbet
# Name: 579 Alt: oceanlab
# Name: 580 Alt: copico
# Name: 581 Alt: droxne
# Name: 582 Alt: version
# Name: 583 Alt: cryptogenic-bullion
# Name: 584 Alt: starta
# Name: 585 Alt: megacoin
# Name: 586 Alt: inflationcoin
# Name: 587 Alt: moin
# Name: 588 Alt: ongsocial
# Name: 589 Alt: guncoin
# Name: 590 Alt: condensate
# Name: 591 Alt: eternity
# Name: 592 Alt: fundyourselfnow
# Name: 593 Alt: kolion
# Name: 594 Alt: growers-international
# Name: 595 Alt: unbreakablecoin
# Name: 596 Alt: trumpcoin
# Name: 597 Alt: smartcoin
# Name: 598 Alt: zero
# Name: 599 Alt: darcrus
# Name: 600 Alt: adzcoin
# Name: 601 Alt: canada-ecoin
# Name: 602 Alt: daxxcoin
# Name: 603 Alt: zennies
# Name: 604 Alt: bitradio
# Name: 605 Alt: minereum
# Name: 606 Alt: adelphoi
# Name: 607 Alt: unitus
# Name: 608 Alt: leviarcoin
# Name: 609 Alt: influxcoin
# Name: 610 Alt: elementrem
# Name: 611 Alt: authorship
# Name: 612 Alt: bata
# Name: 613 Alt: insanecoin-insn
# Name: 614 Alt: cream
# Name: 615 Alt: confido
# Name: 616 Alt: tittiecoin
# Name: 617 Alt: piplcoin
# Name: 618 Alt: kekcoin
# Name: 619 Alt: legends-room
# Name: 620 Alt: teslacoin
# Name: 621 Alt: nekonium
# Name: 622 Alt: zetacoin
# Name: 623 Alt: coinonatx
# Name: 624 Alt: netko
# Name: 625 Alt: lanacoin
# Name: 626 Alt: kurrent
# Name: 627 Alt: fuelcoin
# Name: 628 Alt: desire
# Name: 629 Alt: visio
# Name: 630 Alt: petrodollar
# Name: 631 Alt: centurion
# Name: 632 Alt: sugar-exchange
# Name: 633 Alt: kobocoin
# Name: 634 Alt: dai
# Name: 635 Alt: crystal-clear
# Name: 636 Alt: digitalcoin
# Name: 637 Alt: piggycoin
# Name: 638 Alt: atomic-coin
# Name: 639 Alt: ico-openledger
# Name: 640 Alt: fantomcoin
# Name: 641 Alt: whalecoin
# Name: 642 Alt: tracto
# Name: 643 Alt: trollcoin
# Name: 644 Alt: qubitcoin
# Name: 645 Alt: billionaire-token
# Name: 646 Alt: zcash-gold
# Name: 647 Alt: machinecoin
# Name: 648 Alt: russiacoin
# Name: 649 Alt: accelerator-network
# Name: 650 Alt: smileycoin
# Name: 651 Alt: biblepay
# Name: 652 Alt: nyancoin
# Name: 653 Alt: i0coin
# Name: 654 Alt: kilocoin
# Name: 655 Alt: platinumbar
# Name: 656 Alt: hobonickels
# Name: 657 Alt: ultracoin
# Name: 658 Alt: triangles
# Name: 659 Alt: starcredits
# Name: 660 Alt: skincoin
# Name: 661 Alt: woodcoin
# Name: 662 Alt: fucktoken
# Name: 663 Alt: capricoin
# Name: 664 Alt: wavesgo
# Name: 665 Alt: maxcoin
# Name: 666 Alt: xios
# Name: 667 Alt: pascal-lite
# Name: 668 Alt: bitcoin-scrypt
# Name: 669 Alt: cryptojacks
# Name: 670 Alt: sagacoin
# Name: 671 Alt: rimbit
# Name: 672 Alt: postoken
# Name: 673 Alt: swaptoken
# Name: 674 Alt: 42-coin
# Name: 675 Alt: titcoin
# Name: 676 Alt: etheriya
# Name: 677 Alt: britcoin
# Name: 678 Alt: aricoin
# Name: 679 Alt: bitpark-coin
# Name: 680 Alt: blakestar
# Name: 681 Alt: bitbar
# Name: 682 Alt: rasputin-online-coin
# Name: 683 Alt: opal
# ...
# Name: 764 Alt: ambercoin
# Name: 765 Alt: tekcoin
# Name: 766 Alt: postcoin
# Name: 767 Alt: network-token
# Name: 768 Alt: spacecoin
# Name: 769 Alt: iticoin
# Name: 770 Alt: monkey-project
# Name: 771 Alt: sovereign-hero
# Name: 772 Alt: litecoin-plus
# Name: 773 Alt: eot-token
# Name: 774 Alt: tattoocoin
# Name: 775 Alt: berncash
# Name: 776 Alt: unicoin
# Name: 777 Alt: goldreserve
# Name: 778 Alt: gapcoin
# Name: 779 Alt: sterlingcoin
# Name: 780 Alt: cryptocarbon
# Name: 781 Alt: prototanium
# Name: 782 Alt: mojocoin
# Name: 783 Alt: btsr
# Name: 784 Alt: blakecoin
# Name: 785 Alt: nevacoin
# Name: 786 Alt: satoshimadness
# Name: 787 Alt: bitbtc
# Name: 788 Alt: emerald
# Name: 789 Alt: swing
# Name: 790 Alt: valorbit
# Name: 791 Alt: dalecoin
# Name: 792 Alt: zozocoin
# Name: 793 Alt: tigercoin
# Name: 794 Alt: catcoin
# Name: 795 Alt: chesscoin
# Name: 796 Alt: motocoin
# Name: 797 Alt: icobid
# Name: 798 Alt: ethgas
# Name: 799 Alt: prime-xi
# Name: 800 Alt: bit20
# Name: 801 Alt: ammo-rewards
# Name: 802 Alt: revolvercoin
# Name: 803 Alt: quatloo
# Name: 804 Alt: globalboost-y
# Name: 805 Alt: ebitcoin-cash
# Name: 806 Alt: darsek
# Name: 807 Alt: globalcoin
# Name: 808 Alt: brat
# Name: 809 Alt: securecoin
# Name: 810 Alt: x-coin
# Name: 811 Alt: chronos
# Name: 812 Alt: ethereumcash
# Name: 813 Alt: virta-unique-coin
# Name: 814 Alt: neuro
# Name: 815 Alt: eurocoin
# Name: 816 Alt: kronecoin
# Name: 817 Alt: elcoin-el
# Name: 818 Alt: parallelcoin
# Name: 819 Alt: soilcoin
# Name: 820 Alt: grantcoin
# Name: 821 Alt: zurcoin
# Name: 822 Alt: money
# Name: 823 Alt: argentum
# Name: 824 Alt: ethereum-dark
# Name: 825 Alt: sativacoin
# Name: 826 Alt: grimcoin
# Name: 827 Alt: remicoin
# Name: 828 Alt: eryllium
# Name: 829 Alt: ereal
# Name: 830 Alt: advanced-internet-blocks
# Name: 831 Alt: metal-music-coin
# Name: 832 Alt: icoin
# Name: 833 Alt: hexx
# Name: 834 Alt: iethereum
# Name: 835 Alt: helleniccoin
# Name: 836 Alt: px
# Name: 837 Alt: bitasean
# Name: 838 Alt: marijuanacoin
# Name: 839 Alt: cachecoin
# Name: 840 Alt: idice
# Name: 841 Alt: newbium
# Name: 842 Alt: gameunits
# Name: 843 Alt: paycon
# Name: 844 Alt: ripto-bux
# Name: 845 Alt: philosopher-stones
# Name: 846 Alt: doubloon
# Name: 847 Alt: bitgem
# Name: 848 Alt: mao-zedong
# Name: 849 Alt: bnrtxcoin
# Name: 850 Alt: bumbacoin
# Name: 851 Alt: comet
# Name: 852 Alt: cannation
# Name: 853 Alt: coinonat
# Name: 854 Alt: vault-coin
# Name: 855 Alt: ecocoin
# Name: 856 Alt: rupaya
# Name: 857 Alt: evotion
# Name: 858 Alt: independent-money-system
# Name: 859 Alt: gold-pressed-latinum
# Name: 860 Alt: aquariuscoin
# Name: 861 Alt: virtacoinplus
# Name: 862 Alt: jin-coin
# Name: 863 Alt: globaltoken
# Name: 864 Alt: eaglecoin
# Name: 865 Alt: sproutsextreme
# Name: 866 Alt: beatcoin
# Name: 867 Alt: goldpieces
# Name: 868 Alt: virtualcoin
# Name: 869 Alt: hempcoin-hmp
# Name: 870 Alt: funcoin
# Name: 871 Alt: usde
# Name: 872 Alt: reecoin
# Name: 873 Alt: bipcoin
# Name: 874 Alt: aerium
# Name: 875 Alt: creatio
# Name: 876 Alt: compucoin
# Name: 877 Alt: digital-rupees
# Name: 878 Alt: sixeleven
# Name: 879 Alt: benjirolls
# Name: 880 Alt: bitsilver
# Name: 881 Alt: acoin
# Name: 882 Alt: solarflarecoin
# Name: 883 Alt: quazarcoin
# Name: 884 Alt: tajcoin
# Name: 885 Alt: ronpaulcoin
# Name: 886 Alt: gpu-coin
# Name: 887 Alt: spots
# Name: 888 Alt: flaxscript
# Name: 889 Alt: cybcsec
# Name: 890 Alt: allion
# Name: 891 Alt: bolenum
# Name: 892 Alt: fuzzballs
# Name: 893 Alt: bitgold
# Name: 894 Alt: yacoin
# Name: 895 Alt: zetamicron
# Name: 896 Alt: mustangcoin
# Name: 897 Alt: impact
# Name: 898 Alt: theresa-may-coin
# Name: 899 Alt: wild-beast-block
# Name: 900 Alt: songcoin
# Name: 901 Alt: vaperscoin
# Name: 902 Alt: roofs
# Name: 903 Alt: luna-coin
# Name: 904 Alt: bitcoin-planet
# Name: 905 Alt: allsafe
# Name: 906 Alt: ether-for-the-rest-of-the-world
# Name: 907 Alt: healthywormcoin
# Name: 908 Alt: 300-token
# Name: 909 Alt: cryptoworldx-token
# Name: 910 Alt: leacoin
# Name: 911 Alt: blackstar
# Name: 912 Alt: cthulhu-offerings
# Name: 913 Alt: pulse
# Name: 914 Alt: socialcoin-socc
# Name: 915 Alt: women
# Name: 916 Alt: iconic
# Name: 917 Alt: master-swiscoin
# Name: 918 Alt: slevin
# Name: 919 Alt: piecoin
# Name: 920 Alt: exchangen
# Name: 921 Alt: useless-ethereum-token
# Name: 922 Alt: bios-crypto
# Name: 923 Alt: tychocoin
# Name: 924 Alt: coimatic-3
# Name: 925 Alt: biteur
# Name: 926 Alt: quebecoin
# Name: 927 Alt: artex-coin
# Name: 928 Alt: prcoin
# Name: 929 Alt: torcoin-tor
# Name: 930 Alt: playercoin
# Name: 931 Alt: cashcoin
# Name: 932 Alt: milocoin
# Name: 933 Alt: dollar-online
# Name: 934 Alt: javascript-token
# Name: 935 Alt: argus
# Name: 936 Alt: litecoin-ultra
# Name: 937 Alt: ride-my-car
# Name: 938 Alt: futurexe
# Name: 939 Alt: credence-coin
# Name: 940 Alt: dibcoin
# Name: 941 Alt: printerium
# Name: 942 Alt: geertcoin
# Name: 943 Alt: elysium
# Name: 944 Alt: litecred
# Name: 945 Alt: posex
# Name: 946 Alt: veros
# Name: 947 Alt: kingn-coin
# Name: 948 Alt: levoplus
# Name: 949 Alt: crevacoin
# Name: 950 Alt: agrolifecoin
# Name: 951 Alt: dappster
# Name: 952 Alt: speedcash
# Name: 953 Alt: jobscoin
# Name: 954 Alt: antilitecoin
# Name: 955 Alt: magnum
# Name: 956 Alt: rawcoin2
# Name: 957 Alt: coimatic-2
# Name: 958 Alt: cabbage
# Name: 959 Alt: bitvolt
# Name: 960 Alt: geysercoin
# Name: 961 Alt: nodecoin
# Name: 962 Alt: zonecoin
# Name: 963 Alt: p7coin
# Name: 964 Alt: tristar-coin
# Name: 965 Alt: project-x
# Name: 966 Alt: selfiecoin
# Name: 967 Alt: save-and-gain
# Name: 968 Alt: enigma
# Name: 969 Alt: harmonycoin-hmc
# Name: 970 Alt: digital-credits
# Name: 971 Alt: ebittree-coin
# Name: 972 Alt: digital-money-bits
# Name: 973 Alt: abncoin
# Name: 974 Alt: caliphcoin
# Name: 975 Alt: photon
# Name: 976 Alt: gcoin
# Name: 977 Alt: tao
# Name: 978 Alt: virtacoin
# Name: 979 Alt: chips
# Name: 980 Alt: 808coin
# Name: 981 Alt: janus
# Name: 982 Alt: rustbits
# Name: 983 Alt: inpay
# Name: 984 Alt: yashcoin
# Name: 985 Alt: incakoin
# Name: 986 Alt: smart-investment-fund-token
# Name: 987 Alt: cryptcoin
# Name: 988 Alt: ethereum-movie-venture
# Name: 989 Alt: fimkrypto
# Name: 990 Alt: mincoin
# Name: 991 Alt: popularcoin
# Name: 992 Alt: shorty
# Name: 993 Alt: lottocoin
# Name: 994 Alt: shadowcash
# Name: 995 Alt: bankcoin
# Name: 996 Alt: metalcoin
# Name: 997 Alt: interzone
# Name: 998 Alt: intelligent-trading-tech
# Name: 999 Alt: ganjacoin
# Name: 1000 Alt: wyvern
# Name: 1001 Alt: briacoin
# Name: 1002 Alt: wayguide
# Name: 1003 Alt: blazecoin
# Name: 1004 Alt: secretcoin
# Name: 1005 Alt: shadow-token
# Name: 1006 Alt: mutual-coin
# Name: 1007 Alt: casino
# Name: 1008 Alt: shilling
# Name: 1009 Alt: joincoin
# Name: 1010 Alt: flycoin
# Name: 1011 Alt: islacoin
# Name: 1012 Alt: rubies
# Name: 1013 Alt: freicoin
# Name: 1014 Alt: cypher
# Name: 1015 Alt: sling
# Name: 1016 Alt: btctalkcoin
# Name: 1017 Alt: scorecoin
# Name: 1018 Alt: bitz
# Name: 1019 Alt: firecoin
# Name: 1020 Alt: kittehcoin
# Name: 1021 Alt: franko
# Name: 1022 Alt: wmcoin
# Name: 1023 Alt: sacoin
# Name: 1024 Alt: antibitcoin
# Name: 1025 Alt: dollarcoin
# Name: 1026 Alt: crypto
# Name: 1027 Alt: vector
# Name: 1028 Alt: boostcoin
# Name: 1029 Alt: californium
# Name: 1030 Alt: warp
# Name: 1031 Alt: guccionecoin
# Name: 1032 Alt: unrealcoin
# Name: 1033 Alt: destiny
# Name: 1034 Alt: plncoin
# Name: 1035 Alt: uro
# Name: 1036 Alt: debitcoin
# Name: 1037 Alt: flavorcoin
# Name: 1038 Alt: bitquark
# Name: 1039 Alt: beavercoin
# Name: 1040 Alt: bitcoin-21
# Name: 1041 Alt: dreamcoin
# Name: 1042 Alt: steps
# Name: 1043 Alt: billarycoin
# Name: 1044 Alt: jewels
# Name: 1045 Alt: zayedcoin
# Name: 1046 Alt: mindcoin
# Name: 1047 Alt: asiadigicoin
# Name: 1048 Alt: genstake
# Name: 1049 Alt: ego
# Name: 1050 Alt: gamebet-coin
# Name: 1051 Alt: coexistcoin
# Name: 1052 Alt: vip-tokens
# Name: 1053 Alt: anarchistsprime
# Name: 1054 Alt: rsgpcoin
# Name: 1055 Alt: braincoin
# Name: 1056 Alt: morningstar-payments
# Name: 1057 Alt: orlycoin
# Name: 1058 Alt: mtmgaming
# Name: 1059 Alt: impulsecoin
# Name: 1060 Alt: cryptoescudo
# Name: 1061 Alt: bowscoin
# Name: 1062 Alt: arbit
# Name: 1063 Alt: tagrcoin
# Name: 1064 Alt: crtcoin
# Name: 1065 Alt: osmiumcoin
# Name: 1066 Alt: letitride
# Name: 1067 Alt: high-voltage
# Name: 1068 Alt: ponzicoin
# Name: 1069 Alt: qibuck-asset
# Name: 1070 Alt: corethum
# Name: 1071 Alt: xonecoin
# Name: 1072 Alt: ibank
# Name: 1073 Alt: biobar
# Name: 1074 Alt: frazcoin
# Name: 1075 Alt: gbcgoldcoin
# Name: 1076 Alt: ccminer
# Name: 1077 Alt: sydpak
# Name: 1078 Alt: lex4all
# Name: 1079 Alt: concoin
# Name: 1080 Alt: sojourn
# Name: 1081 Alt: ulatech
# Name: 1082 Alt: pizzacoin
# Name: 1083 Alt: burstocean
# Name: 1084 Alt: applecoin-apw
# Name: 1085 Alt: appcoins
# Name: 1086 Alt: atmcoin
# Name: 1087 Alt: nebulas-token
# Name: 1088 Alt: genaro-network
# Name: 1089 Alt: canyacoin
# Name: 1090 Alt: smartmesh
# Name: 1091 Alt: medishares
# Name: 1092 Alt: game
# Name: 1093 Alt: bibox-token
# Name: 1094 Alt: bitcoin-diamond
# Name: 1095 Alt: micromoney
# Name: 1096 Alt: qlink
# Name: 1097 Alt: energo
# Name: 1098 Alt: olympus-labs
# Name: 1099 Alt: html-coin
# Name: 1100 Alt: bitclave
# Name: 1101 Alt: sophiatx
# Name: 1102 Alt: dew
# Name: 1103 Alt: hyper-pay
# Name: 1104 Alt: qbao
# Name: 1105 Alt: ace
# Name: 1106 Alt: prochain
# Name: 1107 Alt: bitcoinx
# Name: 1108 Alt: stronghands
# Name: 1109 Alt: infchain
# Name: 1110 Alt: ignis
# Name: 1111 Alt: super-bitcoin
# Name: 1112 Alt: segwit2x
# Name: 1113 Alt: naga
# Name: 1114 Alt: cappasity
# Name: 1115 Alt: dimcoin
# Name: 1116 Alt: clubcoin
# Name: 1117 Alt: tezos
# Name: 1118 Alt: fargocoin
# Name: 1119 Alt: win-coin
# Name: 1120 Alt: entcash
# Name: 1121 Alt: comsa-eth
# Name: 1122 Alt: lltoken
# Name: 1123 Alt: bigone-token
# Name: 1124 Alt: maker
# Name: 1125 Alt: ug-token
# Name: 1126 Alt: poly-ai
# Name: 1127 Alt: filecoin
# Name: 1128 Alt: lamden
# Name: 1129 Alt: safecoin
# Name: 1130 Alt: viuly
# Name: 1131 Alt: bitair
# Name: 1132 Alt: comsa-xem
# Name: 1133 Alt: golos-gold
# Name: 1134 Alt: ea-coin
# Name: 1135 Alt: homeblockcoin
# Name: 1136 Alt: htmlcoin
# Name: 1137 Alt: sphre-air
# Name: 1138 Alt: infinitecoin
# Name: 1139 Alt: karmacoin
# Name: 1140 Alt: cubits
# Name: 1141 Alt: uquid-coin
# Name: 1142 Alt: lightning-bitcoin
# Name: 1143 Alt: blockcdn
# Name: 1144 Alt: bitserial
# Name: 1145 Alt: irishcoin
# Name: 1146 Alt: escoro
# Name: 1147 Alt: coupecoin
# Name: 1148 Alt: united-bitcoin
# Name: 1149 Alt: davorcoin
# Name: 1150 Alt: kubera-coin
# Name: 1151 Alt: infinity-economics
# Name: 1152 Alt: golfcoin
# Name: 1153 Alt: tokugawa
# Name: 1154 Alt: ties-network
# Name: 1155 Alt: bitcedi
# Name: 1156 Alt: herocoin
# Name: 1157 Alt: vpncoin
# Name: 1158 Alt: gold-reward-token
# Name: 1159 Alt: sigmacoin
# Name: 1160 Alt: animecoin
# Name: 1161 Alt: strikebitclub
# Name: 1162 Alt: exrnchain
# Name: 1163 Alt: turbocoin
# Name: 1164 Alt: terranova
# Name: 1165 Alt: fidentiax
# Name: 1166 Alt: storjcoin-x
# Name: 1167 Alt: magnetcoin
# Name: 1168 Alt: wandx
# Name: 1169 Alt: cyder
# Name: 1170 Alt: adcoin
# Name: 1171 Alt: magiccoin
# Name: 1172 Alt: peepcoin
# Name: 1173 Alt: pluscoin
# Name: 1174 Alt: pylon-network
# Name: 1175 Alt: cryptopay
# Name: 1176 Alt: neo-gold
# Name: 1177 Alt: starbase
# Name: 1178 Alt: zengold
# Name: 1179 Alt: boscoin
# Name: 1180 Alt: msd
# Name: 1181 Alt: todaycoin
# Name: 1182 Alt: safe-exchange-coin
# Name: 1183 Alt: t-coin
# Name: 1184 Alt: topcoin
# Name: 1185 Alt: dynamiccoin
# Name: 1186 Alt: sisa
# Name: 1187 Alt: bitok
# Name: 1188 Alt: encryptotel-eth
# Name: 1189 Alt: safe-trade-coin
# Name: 1190 Alt: suretly
# Name: 1191 Alt: mergecoin
# Name: 1192 Alt: peacecoin
# Name: 1193 Alt: matryx
# Name: 1194 Alt: fonziecoin
# Name: 1195 Alt: bitsoar
# Name: 1196 Alt: bt1-cst
# Name: 1197 Alt: techshares
# Name: 1198 Alt: paypeer
# Name: 1199 Alt: plexcoin
# Name: 1200 Alt: gaycoin
# Name: 1201 Alt: bestchain
# Name: 1202 Alt: marxcoin
# Name: 1203 Alt: everus
# Name: 1204 Alt: ugain
# Name: 1205 Alt: soma
# Name: 1206 Alt: ur
# Name: 1207 Alt: bt2-cst
# Name: 1208 Alt: btcmoon
# Name: 1209 Alt: alphabitcoinfund
# Name: 1210 Alt: shacoin
# Name: 1211 Alt: protean
# Name: 1212 Alt: sakuracoin
# Name: 1213 Alt: wi-coin
# Name: 1214 Alt: donationcoin
# Name: 1215 Alt: skeincoin
# Name: 1216 Alt: litecoin-gold
# Name: 1217 Alt: xtd-coin
# Name: 1218 Alt: chronologic
# Name: 1219 Alt: bitcoin-silver
# Name: 1220 Alt: wowcoin
# Name: 1221 Alt: international-diamond
# Name: 1222 Alt: hodl-bucks
# Name: 1223 Alt: dimoncoin
# Name: 1224 Alt: corion
# Name: 1225 Alt: aces
# Name: 1226 Alt: india-coin
# Name: 1227 Alt: edrcoin
# Name: 1228 Alt: vulcano
# Name: 1229 Alt: iquant
# Name: 1230 Alt: moneycoin
# Name: 1231 Alt: minex
# Name: 1232 Alt: fapcoin
# Name: 1233 Alt: sharkcoin
# Name: 1234 Alt: yescoin
# Name: 1235 Alt: avoncoin
# Name: 1236 Alt: universalroyalcoin
# Name: 1237 Alt: dutch-coin
# Name: 1238 Alt: francs
# Name: 1239 Alt: anryze
# Name: 1240 Alt: triaconta
# Name: 1241 Alt: compcoin
# Name: 1242 Alt: cycling-coin
# Name: 1243 Alt: phantomx
# Name: 1244 Alt: wearesatoshi
# Name: 1245 Alt: rcoin
# Name: 1246 Alt: runners
# Name: 1247 Alt: musiconomi
# Name: 1248 Alt: bastonet
# Name: 1249 Alt: flappycoin
# Name: 1250 Alt: uncoin
# Name: 1251 Alt: tellurion
# Name: 1252 Alt: blockchain-index
# Name: 1253 Alt: eusd
# Name: 1254 Alt: teamup
# Name: 1255 Alt: stex
# Name: 1256 Alt: eventchain
# Name: 1257 Alt: fazzcoin
# Name: 1258 Alt: sand-coin
# Name: 1259 Alt: ethereum-lite
# Name: 1260 Alt: pirate-blocks
# Name: 1261 Alt: wink
# Name: 1262 Alt: zsecoin
# Name: 1263 Alt: zilbercoin
# Name: 1264 Alt: halloween-coin
# Name: 1265 Alt: ox-fina
# Name: 1266 Alt: rupaya-old
# Name: 1267 Alt: bitcoin2x
# Name: 1268 Alt: akuya-coin
# Name: 1269 Alt: president-trump
# Name: 1270 Alt: elacoin
# Name: 1271 Alt: darklisk
# Name: 1272 Alt: deuscoin
# Name: 1273 Alt: glasscoin
# Name: 1274 Alt: blazercoin
# Name: 1275 Alt: bitfid
# Name: 1276 Alt: fireflycoin
# Name: 1277 Alt: high-gain
# Name: 1278 Alt: macro1
# Name: 1279 Alt: antimatter
# Name: 1280 Alt: uahpay
# Name: 1281 Alt: netbit
# Name: 1282 Alt: aseancoin
# Name: 1283 Alt: primulon
# Name: 1284 Alt: lepen
# Name: 1285 Alt: bitbase
# Name: 1286 Alt: granitecoin
# Name: 1287 Alt: linkedcoin
# Name: 1288 Alt: infinity-pay
# Name: 1289 Alt: huncoin
# Name: 1290 Alt: topaz
# Name: 1291 Alt: birds
# Name: 1292 Alt: moneta2
# Name: 1293 Alt: x2
# Name: 1294 Alt: egold
# Name: 1295 Alt: cybercoin
# Name: 1296 Alt: bubble
# Name: 1297 Alt: landcoin
# Name: 1298 Alt: digital-bullion-gold
# Name: 1299 Alt: psilocybin
# Name: 1300 Alt: lazaruscoin
# Name: 1301 Alt: ibtc
# Name: 1302 Alt: mavro
# Name: 1303 Alt: global-business-revolution
# Name: 1304 Alt: hyper-tv
# Name: 1305 Alt: internet-of-things
# Name: 1306 Alt: thecreed
# Name: 1307 Alt: sportscoin
# Name: 1308 Alt: 10mtoken
# Name: 1309 Alt: first-bitcoin-capital
# Name: 1310 Alt: teslacoilcoin
# Name: 1311 Alt: wa-space
# Name: 1312 Alt: pokecoin
# Name: 1313 Alt: hyper
# Name: 1314 Alt: pinkdog
# Name: 1315 Alt: first-bitcoin
# Name: 1316 Alt: rublebit
# Name: 1317 Alt: cash-poker-pro
# Name: 1318 Alt: regacoin
# Name: 1319 Alt: qora
# Name: 1320 Alt: lathaan
# Name: 1321 Alt: betacoin
# Name: 1322 Alt: namocoin
# Name: 1323 Alt: kashhcoin
# Name: 1324 Alt: royalcoin
# Name: 1325 Alt: cheapcoin
# Name: 1326 Alt: dashs
# Name: 1327 Alt: ebit
# Name: 1328 Alt: goldmaxcoin
# Name: 1329 Alt: quotient
# Name: 1330 Alt: the-vegan-initiative
# Name: 1331 Alt: axiom
# Name: 1332 Alt: yellow-token
# Name: 1333 Alt: swapcoin
# Name: 1334 Alt: teracoin
# Name: 1335 Alt: cbd-crystals
# Name: 1336 Alt: utacoin
# Name: 1337 Alt: faceblock
# Name: 1338 Alt: alpacoin
# Name: 1339 Alt: invisiblecoin
# Name: 1340 Alt: cashme
# Name: 1341 Alt: prismchain
# Name: 1342 Alt: xde-ii
# Name: 1343 Alt: facecoin
# Name: 1344 Alt: snakeeyes
# Name: 1345 Alt: pabyosi-coin-special
# Name: 1346 Alt: 9coin
# Name: 1347 Alt: shellcoin
# Name: 1348 Alt: voyacoin
# Name: 1349 Alt: eggcoin
# Name: 1350 Alt: tattoocoin-limited
# Name: 1351 Alt: frankywillcoin
# Name: 1352 Alt: mmxvi
# Name: 1353 Alt: gameleaguecoin
# Name: 1354 Alt: bitalphacoin
# Name: 1355 Alt: eltc
# Name: 1356 Alt: happy-creator-coin
# Name: 1357 Alt: opescoin
# Name: 1358 Alt: dubstep
# Name: 1359 Alt: xaucoin
# Name: 1360 Alt: trickycoin
# Name: 1361 Alt: operand
# Name: 1362 Alt: omicron
# Name: 1363 Alt: deltacredits
# Name: 1364 Alt: mobilecash
# Name: 1365 Alt: peoplecoin
# Name: 1366 Alt: richcoin
# Name: 1367 Alt: natcoin
# Name: 1368 Alt: goldunioncoin
# Name: 1369 Alt: batcoin
# Name: 1370 Alt: rabbitcoin
# Name: 1371 Alt: bongger
# Name: 1372 Alt: futcoin
# Name: 1373 Alt: avatarcoin
# Name: 1374 Alt: ocow
# Name: 1375 Alt: president-johnson
# Name: 1376 Alt: rhfcoin
# Name: 1377 Alt: aidos-kuneen
# Name: 1378 Alt: royalties
# Name: 1379 Alt: embercoin
# Name: 1380 Alt: xylo
# Name: 1381 Alt: santa-coin
# Name: 1382 Alt: madcoin
# Name: 1383 Alt: casinocoin
# Name: 1384 Alt: bitcoin-unlimited
# Name: 1385 Alt: qcash
# Name: 1386 Alt: farstcoin
